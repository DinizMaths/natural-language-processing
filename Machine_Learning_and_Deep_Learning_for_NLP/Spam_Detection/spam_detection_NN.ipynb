# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer

from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
df = pd.read_csv("https://raw.githubusercontent.com/mohitgupta-1O1/Kaggle-SMS-Spam-Collection-Dataset-/master/spam.csv", encoding='ISO-8859-1')[["v1", "v2"]].rename(columns={"v1": "label", "v2": "text"})

df.head()
# Out:
#   label                                               text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(df["label"])

# %%
X_train, X_test, y_train, y_test = train_test_split(df["text"].values, y, test_size=0.3, random_state=42, stratify=df["label"])

# %%
vectorizer = CountVectorizer()
vectorizer.fit(X_train)

X_train = vectorizer.transform(X_train)
X_test = vectorizer.transform(X_test)

X_train.shape
# Out:
# (3900, 7202)

# %%
model = Sequential(name="spam_detector")

model.add(Dense(10, activation="relu", input_dim=X_train.shape[1]))
model.add(Dropout(0.1))
model.add(Dense(8, activation="relu"))
model.add(Dropout(0.1))
model.add(Dense(1, activation="sigmoid"))

model.compile(loss="mse", optimizer="adam", metrics=["accuracy"])
model.summary()
# Out:
# Model: "spam_detector"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_33 (Dense)            (None, 10)                72030
#
#  dropout_20 (Dropout)        (None, 10)                0
#
#  dense_34 (Dense)            (None, 8)                 88
#
#  dropout_21 (Dropout)        (None, 8)                 0
#
#  dense_35 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 72127 (281.75 KB)
# Trainable params: 72127 (281.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=100, batch_size=10, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 390/390 [==============================] - 2s 4ms/step - loss: 0.0814 - accuracy: 0.9272 - val_loss: 0.0201 - val_accuracy: 0.9809
# Epoch 2/100
# 390/390 [==============================] - 1s 3ms/step - loss: 0.0141 - accuracy: 0.9879 - val_loss: 0.0136 - val_accuracy: 0.9844
# Epoch 3/100
# 390/390 [==============================] - 1s 3ms/step - loss: 0.0069 - accuracy: 0.9931 - val_loss: 0.0119 - val_accuracy: 0.9856
# Epoch 4/100
# 390/390 [==============================] - 2s 5ms/step - loss: 0.0036 - accuracy: 0.9962 - val_loss: 0.0113 - val_accuracy: 0.9868
# Epoch 5/100
# 390/390 [==============================] - 2s 4ms/step - loss: 0.0031 - accuracy: 0.9944 - val_loss: 0.0115 - val_accuracy: 0.9856
# Epoch 6/100
# 390/390 [==============================] - 1s 3ms/step - loss: 0.0025 - accuracy: 0.9962 - val_loss: 0.0124 - val_accuracy: 0.9862
# Epoch 7/100
# 390/390 [==============================] - 1s 3ms/step - loss: 0.0015 - accuracy: 0.9979 - val_loss: 0.0125 - val_accuracy: 0.9862
# Epoch 8/100
# 390/390 [==============================] - 1s 3ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.0119 - val_accuracy: 0.9868
# Epoch 9/100
# 390/390 [==============================] - 1s 3ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0117 - val_accuracy: 0.9868
# Epoch 10/100
# 390/390 [==============================] - 2s 5ms/step - loss: 8.3290e-04 - accuracy: 0.9995 - val_loss: 0.0123 - val_accuracy: 0.9874
# Epoch 11/100
# 390/390 [==============================] - 2s 5ms/step - loss: 7.8387e-04 - accuracy: 0.9997 - val_loss: 0.0121 - val_accuracy: 0.9868
# Epoch 12/100
# 390/390 [==============================] - 1s 3ms/step - loss: 9.3731e-04 - accuracy: 0.9997 - val_loss: 0.0119 - val_accuracy: 0.9862
# Epoch 13/100
# 390/390 [==============================] - 1s 3ms/step - loss: 5.7942e-04 - accuracy: 0.9995 - val_loss: 0.0124 - val_accuracy: 0.9862
# Epoch 14/100
# 390/390 [==============================] - 1s 3ms/step - loss: 5.1632e-04 - accuracy: 0.9997 - val_loss: 0.0120 - val_accuracy: 0.9868
# Epoch 15/100
# 390/390 [==============================] - 1s 3ms/step - loss: 5.3933e-04 - accuracy: 1.0000 - val_loss: 0.0124 - val_accuracy: 0.9862
# Epoch 16/100
# 390/390 [==============================] - 1s 3ms/step - loss: 4.3579e-04 - accuracy: 1.0000 - val_loss: 0.0131 - val_accuracy: 0.9850
# Epoch 17/100
# 390/390 [==============================] - 1s 3ms/step - loss: 5.7167e-04 - accuracy: 0.9995 - val_loss: 0.0127 - val_accuracy: 0.9862
# Epoch 18/100
# 390/390 [==============================] - 2s 5ms/step - loss: 6.1374e-04 - accuracy: 0.9995 - val_loss: 0.0116 - val_accuracy: 0.9874
# Epoch 19/100
# 390/390 [==============================] - 2s 4ms/step - loss: 4.5532e-04 - accuracy: 1.0000 - val_loss: 0.0126 - val_accuracy: 0.9856
# Epoch 20/100
# 390/390 [==============================] - 1s 3ms/step - loss: 3.4757e-04 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 0.9868
# Epoch 21/100
# 390/390 [==============================] - 1s 3ms/step - loss: 3.8272e-04 - accuracy: 1.0000 - val_loss: 0.0131 - val_accuracy: 0.9862
# Epoch 22/100
# 390/390 [==============================] - 1s 3ms/step - loss: 2.9874e-04 - accuracy: 1.0000 - val_loss: 0.0132 - val_accuracy: 0.9862
# Epoch 23/100
# 390/390 [==============================] - 1s 3ms/step - loss: 3.3689e-04 - accuracy: 0.9997 - val_loss: 0.0135 - val_accuracy: 0.9862
# Epoch 24/100
# 390/390 [==============================] - 1s 3ms/step - loss: 3.2404e-04 - accuracy: 1.0000 - val_loss: 0.0139 - val_accuracy: 0.9856
# Epoch 25/100
# 390/390 [==============================] - 2s 5ms/step - loss: 2.7775e-04 - accuracy: 1.0000 - val_loss: 0.0144 - val_accuracy: 0.9839
# Epoch 26/100
# 390/390 [==============================] - 1s 4ms/step - loss: 1.5167e-04 - accuracy: 1.0000 - val_loss: 0.0144 - val_accuracy: 0.9833
# Epoch 27/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1.6870e-04 - accuracy: 1.0000 - val_loss: 0.0141 - val_accuracy: 0.9844
# Epoch 28/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1.1409e-04 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 0.9856
# Epoch 29/100
# 390/390 [==============================] - 1s 3ms/step - loss: 9.6663e-05 - accuracy: 1.0000 - val_loss: 0.0137 - val_accuracy: 0.9856
# Epoch 30/100
# 390/390 [==============================] - 1s 3ms/step - loss: 4.8255e-05 - accuracy: 1.0000 - val_loss: 0.0132 - val_accuracy: 0.9856
# Epoch 31/100
# 390/390 [==============================] - 1s 3ms/step - loss: 3.0446e-04 - accuracy: 1.0000 - val_loss: 0.0139 - val_accuracy: 0.9856
# Epoch 32/100
# 390/390 [==============================] - 2s 5ms/step - loss: 9.3000e-05 - accuracy: 1.0000 - val_loss: 0.0140 - val_accuracy: 0.9850
# Epoch 33/100
# 390/390 [==============================] - 2s 5ms/step - loss: 1.5834e-04 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 0.9839
# Epoch 34/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1.9868e-04 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 0.9862
# Epoch 35/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1.1244e-04 - accuracy: 1.0000 - val_loss: 0.0139 - val_accuracy: 0.9856
# Epoch 36/100
# 390/390 [==============================] - 1s 3ms/step - loss: 2.1663e-04 - accuracy: 1.0000 - val_loss: 0.0147 - val_accuracy: 0.9850
# Epoch 37/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1.9648e-04 - accuracy: 1.0000 - val_loss: 0.0136 - val_accuracy: 0.9856
# Epoch 38/100
# 390/390 [==============================] - 1s 3ms/step - loss: 5.5089e-04 - accuracy: 0.9995 - val_loss: 0.0140 - val_accuracy: 0.9856
# Epoch 39/100
# 390/390 [==============================] - 1s 3ms/step - loss: 8.1467e-05 - accuracy: 1.0000 - val_loss: 0.0141 - val_accuracy: 0.9850
# Epoch 40/100
# 390/390 [==============================] - 2s 4ms/step - loss: 1.1426e-04 - accuracy: 1.0000 - val_loss: 0.0147 - val_accuracy: 0.9844
# Epoch 41/100
# 390/390 [==============================] - 2s 5ms/step - loss: 5.8013e-05 - accuracy: 1.0000 - val_loss: 0.0138 - val_accuracy: 0.9856
# Epoch 42/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1.2205e-04 - accuracy: 1.0000 - val_loss: 0.0136 - val_accuracy: 0.9856
# Epoch 43/100
# 390/390 [==============================] - 1s 3ms/step - loss: 5.6537e-05 - accuracy: 1.0000 - val_loss: 0.0136 - val_accuracy: 0.9856
# Epoch 44/100
# 390/390 [==============================] - 1s 3ms/step - loss: 8.7532e-05 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 0.9862
# Epoch 45/100
# 390/390 [==============================] - 1s 3ms/step - loss: 4.0890e-05 - accuracy: 1.0000 - val_loss: 0.0134 - val_accuracy: 0.9862
# Epoch 46/100
# 390/390 [==============================] - 1s 3ms/step - loss: 8.4869e-05 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 0.9862
# Epoch 47/100
# 390/390 [==============================] - 2s 5ms/step - loss: 4.7610e-05 - accuracy: 1.0000 - val_loss: 0.0132 - val_accuracy: 0.9862
# Epoch 48/100
# 390/390 [==============================] - 2s 4ms/step - loss: 3.8304e-05 - accuracy: 1.0000 - val_loss: 0.0137 - val_accuracy: 0.9856
# Epoch 49/100
# 390/390 [==============================] - 1s 3ms/step - loss: 6.0426e-05 - accuracy: 1.0000 - val_loss: 0.0143 - val_accuracy: 0.9856
# Epoch 50/100
# 390/390 [==============================] - 1s 3ms/step - loss: 4.2937e-05 - accuracy: 1.0000 - val_loss: 0.0143 - val_accuracy: 0.9856
# Epoch 51/100
# 390/390 [==============================] - 1s 3ms/step - loss: 2.4822e-04 - accuracy: 0.9997 - val_loss: 0.0129 - val_accuracy: 0.9862
# Epoch 52/100
# 390/390 [==============================] - 1s 3ms/step - loss: 5.5143e-05 - accuracy: 1.0000 - val_loss: 0.0126 - val_accuracy: 0.9862
# Epoch 53/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1.2016e-04 - accuracy: 1.0000 - val_loss: 0.0127 - val_accuracy: 0.9862
# Epoch 54/100
# 390/390 [==============================] - 2s 5ms/step - loss: 2.4482e-04 - accuracy: 0.9997 - val_loss: 0.0138 - val_accuracy: 0.9856
# Epoch 55/100
# 390/390 [==============================] - 2s 5ms/step - loss: 7.0237e-05 - accuracy: 1.0000 - val_loss: 0.0131 - val_accuracy: 0.9862
# Epoch 56/100
# 390/390 [==============================] - 1s 3ms/step - loss: 8.4839e-06 - accuracy: 1.0000 - val_loss: 0.0131 - val_accuracy: 0.9862
# Epoch 57/100
# 390/390 [==============================] - 1s 3ms/step - loss: 7.4740e-05 - accuracy: 1.0000 - val_loss: 0.0137 - val_accuracy: 0.9856
# Epoch 58/100
# 390/390 [==============================] - 1s 3ms/step - loss: 2.2831e-05 - accuracy: 1.0000 - val_loss: 0.0126 - val_accuracy: 0.9868
# Epoch 59/100
# 390/390 [==============================] - 1s 3ms/step - loss: 4.8768e-05 - accuracy: 1.0000 - val_loss: 0.0145 - val_accuracy: 0.9856
# Epoch 60/100
# 390/390 [==============================] - 1s 3ms/step - loss: 3.7916e-05 - accuracy: 1.0000 - val_loss: 0.0141 - val_accuracy: 0.9856
# Epoch 61/100
# 390/390 [==============================] - 1s 3ms/step - loss: 9.2682e-05 - accuracy: 1.0000 - val_loss: 0.0128 - val_accuracy: 0.9868
# Epoch 62/100
# 390/390 [==============================] - 2s 5ms/step - loss: 5.0842e-05 - accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 0.9868
# Epoch 63/100
# 390/390 [==============================] - 1s 4ms/step - loss: 3.9074e-05 - accuracy: 1.0000 - val_loss: 0.0130 - val_accuracy: 0.9862
# Epoch 64/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1.7384e-04 - accuracy: 0.9997 - val_loss: 0.0135 - val_accuracy: 0.9862
# Epoch 65/100
# 390/390 [==============================] - 1s 3ms/step - loss: 2.5442e-05 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 0.9862
# Epoch 66/100
# 390/390 [==============================] - 1s 3ms/step - loss: 5.6852e-05 - accuracy: 1.0000 - val_loss: 0.0140 - val_accuracy: 0.9850
# Epoch 67/100
# 390/390 [==============================] - 1s 3ms/step - loss: 5.5170e-05 - accuracy: 1.0000 - val_loss: 0.0136 - val_accuracy: 0.9862
# Epoch 68/100
# 390/390 [==============================] - 2s 5ms/step - loss: 5.8910e-05 - accuracy: 1.0000 - val_loss: 0.0137 - val_accuracy: 0.9856
# Epoch 69/100
# 390/390 [==============================] - 1s 3ms/step - loss: 4.3519e-05 - accuracy: 1.0000 - val_loss: 0.0137 - val_accuracy: 0.9856
# Epoch 70/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1.7101e-04 - accuracy: 0.9997 - val_loss: 0.0142 - val_accuracy: 0.9856
# Epoch 71/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1.1502e-05 - accuracy: 1.0000 - val_loss: 0.0137 - val_accuracy: 0.9856
# Epoch 72/100
# 390/390 [==============================] - 1s 3ms/step - loss: 4.6053e-06 - accuracy: 1.0000 - val_loss: 0.0136 - val_accuracy: 0.9856
# Epoch 73/100
# 390/390 [==============================] - 1s 3ms/step - loss: 3.0515e-05 - accuracy: 1.0000 - val_loss: 0.0132 - val_accuracy: 0.9856
# Epoch 74/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1.9468e-05 - accuracy: 1.0000 - val_loss: 0.0139 - val_accuracy: 0.9856
# Epoch 75/100
# 390/390 [==============================] - 1s 3ms/step - loss: 3.2132e-05 - accuracy: 1.0000 - val_loss: 0.0137 - val_accuracy: 0.9856
# Epoch 76/100
# 390/390 [==============================] - 2s 5ms/step - loss: 2.5506e-05 - accuracy: 1.0000 - val_loss: 0.0138 - val_accuracy: 0.9856
# Epoch 77/100
# 390/390 [==============================] - 1s 3ms/step - loss: 2.2898e-05 - accuracy: 1.0000 - val_loss: 0.0145 - val_accuracy: 0.9856
# Epoch 78/100
# 390/390 [==============================] - 1s 3ms/step - loss: 2.1610e-04 - accuracy: 0.9997 - val_loss: 0.0145 - val_accuracy: 0.9856
# Epoch 79/100
# 390/390 [==============================] - 1s 3ms/step - loss: 2.4925e-05 - accuracy: 1.0000 - val_loss: 0.0147 - val_accuracy: 0.9850
# Epoch 80/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1.3375e-05 - accuracy: 1.0000 - val_loss: 0.0147 - val_accuracy: 0.9850
# Epoch 81/100
# 390/390 [==============================] - 1s 4ms/step - loss: 2.4977e-05 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 0.9850
# Epoch 82/100
# 390/390 [==============================] - 1s 3ms/step - loss: 6.0732e-06 - accuracy: 1.0000 - val_loss: 0.0145 - val_accuracy: 0.9856
# Epoch 83/100
# 390/390 [==============================] - 2s 5ms/step - loss: 1.7396e-05 - accuracy: 1.0000 - val_loss: 0.0144 - val_accuracy: 0.9856
# Epoch 84/100
# 390/390 [==============================] - 2s 5ms/step - loss: 2.1516e-05 - accuracy: 1.0000 - val_loss: 0.0140 - val_accuracy: 0.9856
# Epoch 85/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1.5345e-05 - accuracy: 1.0000 - val_loss: 0.0140 - val_accuracy: 0.9850
# Epoch 86/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1.1968e-05 - accuracy: 1.0000 - val_loss: 0.0140 - val_accuracy: 0.9850
# Epoch 87/100
# 390/390 [==============================] - 1s 3ms/step - loss: 2.1209e-05 - accuracy: 1.0000 - val_loss: 0.0138 - val_accuracy: 0.9850
# Epoch 88/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1.2000e-05 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 0.9850
# Epoch 89/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1.6525e-04 - accuracy: 0.9997 - val_loss: 0.0135 - val_accuracy: 0.9856
# Epoch 90/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1.1538e-05 - accuracy: 1.0000 - val_loss: 0.0137 - val_accuracy: 0.9856
# Epoch 91/100
# 390/390 [==============================] - 2s 6ms/step - loss: 8.9497e-06 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 0.9850
# Epoch 92/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1.9629e-05 - accuracy: 1.0000 - val_loss: 0.0162 - val_accuracy: 0.9827
# Epoch 93/100
# 390/390 [==============================] - 1s 3ms/step - loss: 2.0949e-05 - accuracy: 1.0000 - val_loss: 0.0137 - val_accuracy: 0.9856
# Epoch 94/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1.6956e-05 - accuracy: 1.0000 - val_loss: 0.0141 - val_accuracy: 0.9850
# Epoch 95/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1.8762e-05 - accuracy: 1.0000 - val_loss: 0.0153 - val_accuracy: 0.9844
# Epoch 96/100
# 390/390 [==============================] - 2s 5ms/step - loss: 1.3395e-05 - accuracy: 1.0000 - val_loss: 0.0161 - val_accuracy: 0.9833
# Epoch 97/100
# 390/390 [==============================] - 2s 6ms/step - loss: 1.2678e-04 - accuracy: 0.9997 - val_loss: 0.0160 - val_accuracy: 0.9833
# Epoch 98/100
# 390/390 [==============================] - 1s 3ms/step - loss: 9.9271e-06 - accuracy: 1.0000 - val_loss: 0.0159 - val_accuracy: 0.9833
# Epoch 99/100
# 390/390 [==============================] - 1s 3ms/step - loss: 2.3033e-04 - accuracy: 0.9997 - val_loss: 0.0165 - val_accuracy: 0.9827
# Epoch 100/100
# 390/390 [==============================] - 1s 3ms/step - loss: 1.1977e-04 - accuracy: 0.9997 - val_loss: 0.0164 - val_accuracy: 0.9833

# %%
loss, accuracy = model.evaluate(X_test, y_test)

print(loss)
print(accuracy)
# Out:
# 53/53 [==============================] - 0s 4ms/step - loss: 0.0164 - accuracy: 0.9833
# 0.016417331993579865
# 0.9832535982131958
